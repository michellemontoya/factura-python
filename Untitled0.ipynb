# %% [markdown]
# <a href="https://colab.research.google.com/github/michellemontoya/factura-python/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Registro:
    def registro(self):
        print("////////////¡BIENBENID@S!////////////")

        print("--------EL PEQUE NEQUI---------")

        print("===============================================")
        print("digite sus datos para crear una cuenta")
        print("===============================================")

        self.nombres = str(input("Escriba su nombre: "))
        self.apellidos = str(input("Escriba su apellido: "))
        self.telefono = int(input("Escriba su numero de telefono: "))
        self.edad = int(input("Escriba su edad: "))
        self.contrasena = input("Cree una contraseña: ")
        self.usuario = input("Digite su usuario:")
        print("------------CUENTA CREADA CORRECTAMENTE-------------")

        print("----------------------------------------------------")


class Entrada(Registro):
    def __init__(self):
        super().registro()
        print("datos para iniciar secion : ")
        self._nombreuser=str(input("\tEscriba su usuario : "))
        self._contrasenauser=str(input("\tEscriba su contraseña : "))        
        if self._nombreuser==self.usuario and self._contrasenauser==self.contrasena:

            print("==================================================")
            print(" ===============BIENVENIDO===========\n\
             haz iniciado secion CORRECTAMENTE.")
            
        else:
            print("OJO!!\n\
            contraseña o usuario incorrecto, por su seguridad debes volver a iniciar secion")
            exit()

print("____________________________________________________________________________")

class Utilizacion (Entrada):
        def __init__(self):

          super().__init__()
          total=0
          comprobar= True
          while comprobar == True:
            
            print("  EL PEQUE NEQUI\n\
            1. -ingresar dinero\n\
            2. -sacar dinero\n\
            3. -Salir\n")


            opcion=int(input("INGRESE LA OPCION QUE DESEAS : "))


            

            if opcion==1:
                ingresar=float(input("\tcuanto dinero deseas consignar : "))
                total=total+ingresar
                print(f"\tsu consignacion por {ingresar} pesos fue un exito")
                print(f"\t Su saldo es de {total} pesos")
            elif opcion==2:
                retirar=float(input("\tcuanto dinero desas retirar : "))
                
                if retirar<total:
                    total=total-retirar
                    print(f"\tsu retiro por {retirar} pesos fue exitoso")
                    print(f"\tsu saldo es de {total} pesos ")
                else :
                    print(f"\tUy, no tienes los suficientes fondos para hacer este retiro. Tu saldo es de {total} pesos")
            elif opcion==3:
                print("\tHAZ CERRADO SECION CORRECTAMENTE.")
                return
            else:
                print("\topcion incorrecta")


cliente1=Utilizacion()
# Out:
# ______________________________________________________________________________________
# ////////////¡BIENBENID@S!////////////
# --------EL PEQUE NEQUI---------
# ...
# digite sus datos para crear una cuenta
# ...
# Escriba su nombre: danna
# Escriba su apellido: montoya
# Escriba su numero de telefono: 3123215678
# Escriba su edad: 18
# Cree una contraseña: mich123
# Digite su usuario:danita@gmail.com
# ------------CUENTA CREADA CORRECTAMENTE-------------
# ----------------------------------------------------
# datos para iniciar secion :
# 	Escriba su usuario : danita@gmail.com
# 	Escriba su contraseña : mich123
# ...
#  ===============BIENVENIDO===========
#              haz iniciado secion CORRECTAMENTE.
#   EL PEQUE NEQUI
#             1. -ingresar dinero
#             2. -Sacar dinero
#             3. -Salir
#
# INGRESE LA OPCION QUE DESEAS : 250000
# 	opcion incorrecta
#   EL PEQUE NEQUI
#             1. -ingresar dinero
#             2. -Sacar dinero
#             3. -Salir
#
# ...

# %% [markdown]
# ![diagra nequi.PNG](data:image/png;base64,...)
